# %% [markdown]
# ### Intermediate+ Starts Here

# %% [markdown]
# ### Email SMTP and datetime

# %% [markdown]
# #### Day 32: Automated Birthday Wisher Project

# %% [markdown]
# Day 33

# %% [markdown]
# Day 34

# %% [markdown]
# Day 35

# %% [markdown]
# Day 36

# %% [markdown]
# Day 37

# %% [markdown]
# Day 38

# %% [markdown]
# Day 39

# %% [markdown]
# Day 40

# %% [markdown]
# Day 45

# %% [markdown]
# Day 46

# %% [markdown]
# Day 47

# %% [markdown]
# Day 48

# %% [markdown]
# Day 49

# %% [markdown]
# Day 50

# %% [markdown]
# Day 51

# %% [markdown]
# Day 52

# %% [markdown]
# Day 53

# %% [markdown]
# Day 54

# %% [markdown]
# Day 55

# %% [markdown]
# Day 56

# %% [markdown]
# Day 57
